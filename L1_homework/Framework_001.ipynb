# %%
# 这是智能生成小程序的程序骨架
# 首先是数据载入部分
def inputData(database1):
 print (database1)

#定义设计目的
def defAim(aim):
 print (aim)

#导入公用库的设计素材
def inputGeneralData(database):
 print (database)

#进行项目数据整理
def reviewData(review):
 print(review)

    
print ("------------------------")
inputData("项目初始数据")
defAim("设计目的")
inputGeneralData("素材库数据")
print ("------------------------")
print ("------------------------")
print ("------------------------")

#功能场景确定
def defFunction(functions):
 print(functions)

#素材处理
def anaElements(element):
 print(element)

#框架与脚本生成
def scriptGenerate(script):
 print(script)

#游戏数值生成
def formulaGenerate(formula):
 print(formula)

#游戏美术设计生成
def designGenerate(design):
 print(design)


#游戏美术设计决策
def decisionMaking(decision):
 print(decision)

#方案输出
def gameOutput(game):
 print(game)

print ("-----游戏逻辑设计中-------")
print ("------------------------")
defFunction("功能场景确定")
anaElements("素材处理")
scriptGenerate("框架与脚本生成")
formulaGenerate("游戏数值生成")
print ("-----游戏逻辑设计完毕------")
print ("------------------------")
print ("-----游戏美术设计---------")
designGenerate("游戏美术设计生成")
decisionMaking("游戏美术设计决策")
print ("------------------------")

print ("-------最终产出输出--------")
gameOutput("产出输出")

print ("------------------------")
# Out:
# ------------------------
# 项目初始数据
# 设计目的
# 素材库数据
# ------------------------
# ------------------------
# ------------------------
# -----游戏逻辑设计中-------
# ------------------------
# 功能场景确定
# 素材处理
# 框架与脚本生成
# 游戏数值生成
# -----游戏逻辑设计完毕------
# ------------------------
# -----游戏美术设计---------
# 游戏美术设计生成
# 游戏美术设计决策
# ------------------------
# -------最终产出输出--------
# 产出输出
# ------------------------
